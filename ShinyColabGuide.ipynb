# %% [markdown]
# <a href="https://colab.research.google.com/github/JulTob/Wiki-Documentation/blob/master/ShinyColabGuide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interactive Colab Guide

# %% [markdown]
# ## HTML + JavaScript
# Hyper-Text Markup Language, HTML, is the most common programming paradigm in the world, by sheer volume. Every webpage is built on it.
#
# Colab, even if originally aimed at python, has a feature to build **magic cells**. Preceed html cells with `%%html` to tell colab to interpret it as such.
#
# Inside it, you can use Javascript as any webpage would.

# %%
# %%html
# <input id="user-input" type="number" value="2">
# <button onclick="calculate()">Compute Square</button>
#
# <p id="calc-result"></p>
#
# <script>
# function calculate() {
#     // 1. Get the number the student typed
#     let value = document
#         .getElementById("user-input")
#         .value;
#
#     // 2. Do the math
#     let result = value * value;
#
#     // 3. Show the result
#     document
#         .getElementById("calc-result")
#         .innerText = "Result: " + result;
#     }
#     </script>
# Out:
# <input id="user-input" type="number" value="2">
# <button onclick="calculate()">Compute Square</button>
#
# <p id="calc-result"></p>
#
# <script>
# function calculate() {
#     // 1. Get the number the student typed
#     let value = document
#         .getElementById("user-input")
#         .value;
#
#     // 2. Do the math
#     let result = value * value;
#
#     // 3. Show the result
#     document
#         .getElementById("calc-result")
#         .innerText = "Result: " + result;
#     }
#     </script>

# %% [markdown]
# ## SVG Integration
#
# You can also embed Scalable Vector Graphics (SVG) directly into your Colab notebook using the same `%%html` magic command.

# %%
# %%html
# <svg width="200" height="200">
#     <circle cx="100"
#             cy="100"
#             r="80"
#             stroke="red" stroke-width="4"
#             fill="tomato" />
#     <text
#         x="50%" y="50%"
#         text-anchor="middle"
#         fill="black" font-size="20px"
#         dy=".3em">SVG Circle</text>
#     </svg>
# Out:
# <svg width="200" height="200">
#     <circle cx="100"
#             cy="100"
#             r="80"
#             stroke="red" stroke-width="4"
#             fill="tomato" />
#     <text
#         x="50%" y="50%"
#         text-anchor="middle"
#         fill="black" font-size="20px"
#         dy=".3em">SVG Circle</text>
#     </svg>

# %% [markdown]
# # Animating svg

# %%
# %%html
# <svg width="400" height="400">
#     <circle id="animated-circle"
#             cx="50%"
#             cy="50%"
#             r="80"
#             stroke="red" stroke-width="4"
#             fill="tomato" />
#     <text
#         x="50%" y="50%"
#         text-anchor="middle"
#         fill="black" font-size="20px"
#         dy=".3em">SVG Circle</text>
# </svg>
# <br>
# <button onclick="startAnimation()">Animate Circle</button>
#
# <script>
# let animating = false;
# let r = 100;
# let growing = false;
#
# function startAnimation() {
#     if (animating) return; // Prevent multiple loops
#     animating = true;
#     let circle = document.getElementById("animated-circle");
#
#     r1 = 120;
#     r0 = 80;
#     dr = (r1 - r0)/(r1+r0) ;
#     function frame() {
#         d1 = (r-r0)/(r1+r0);
#         d0 = (r1-r)/(r1+r0);
#         if (growing) {
#             r += d0 + dr/100;
#             if (r >= r1) growing = false;
#         } else {
#             r -= d1 + dr/100;
#             if (r <= r0) growing = true;
#         }
#         circle.setAttribute("r", r);
#         requestAnimationFrame(frame);
#     }
#
#     requestAnimationFrame(frame);
# }
# </script>
# Out:
# <svg width="400" height="400">
#     <circle id="animated-circle"
#             cx="50%"
#             cy="50%"
#             r="80"
#             stroke="red" stroke-width="4"
#             fill="tomato" />
#     <text
#         x="50%" y="50%"
#         text-anchor="middle"
#         fill="black" font-size="20px"
#         dy=".3em">SVG Circle</text>
# </svg>
# <br>
# <button onclick="startAnimation()">Animate Circle</button>
#
# <script>
# let animating = false;
# let r = 100;
# let growing = false;
#
# function startAnimation() {
#     if (animating) return; // Prevent multiple loops
#     animating = true;
#     let circle = document.getElementById("animated-circle");
#
#     r1 = 120;
#     r0 = 80;
#     dr = (r1 - r0)/(r1+r0) ;
#     function frame() {
#         d1 = (r-r0)/(r1+r0);
#         d0 = (r1-r)/(r1+r0);
#         if (growing) {
#             r += d0 + dr/100;
#             if (r >= r1) growing = false;
#         } else {
#             r -= d1 + dr/100;
#             if (r <= r0) growing = true;
#         }
#         circle.setAttribute("r", r);
#         requestAnimationFrame(frame);
#     }
#
#     requestAnimationFrame(frame);
# }
# </script>

# %%
# %%html
# <input type="range" min="0" max="10" value="5" id="my-slider" oninput="updateSlider()">
#
# <p id="slider-display"></p>
#
# <script>
# function updateSlider() {
#   let v = document.getElementById("my-slider").value;
#   document.getElementById("slider-display").innerText = "Current Value: " + v;
# }
# </script>
# Out:
# <input type="range" min="0" max="10" value="5" id="my-slider" oninput="updateSlider()">
#
# <p id="slider-display"></p>
#
# <script>
# function updateSlider() {
#   let v = document.getElementById("my-slider").value;
#   document.getElementById("slider-display").innerText = "Current Value: " + v;
# }
# </script>

# %%
# %%html
# <div style="text-align: center; width: 300px;">
#   <svg width="200" height="200">
#     <!-- A rectangle with rx and ry equal to half its width/height is a circle -->
#     <rect id="morph-shape"
#           x="10" y="10"
#           width="180" height="180"
#           rx="90" ry="90"
#           fill="tomato"
#           stroke="red" stroke-width="4" />
#   </svg>
#   <br><br>
#   <input type="range" id="morph-slider" min="0" max="90" value="90" oninput="morphShape()" style="width: 100%;">
#   <p id="morph-label">Shape: Circle (rx=90)</p>
# </div>
#
# <script>
# function morphShape() {
#   let sliderValue = document.getElementById("morph-slider").value;
#   let shape = document.getElementById("morph-shape");
#   let label = document.getElementById("morph-label");
#
#   // Update the corner radius
#   shape.setAttribute("rx", sliderValue);
#   shape.setAttribute("ry", sliderValue);
#
#   // Update the label text
#   if (sliderValue == 0) {
#       label.innerText = "Shape: Square (rx=0)";
#   } else if (sliderValue == 90) {
#       label.innerText = "Shape: Circle (rx=90)";
#   } else {
#       label.innerText = "Shape: Squircle (rx=" + sliderValue + ")";
#   }
# }
# </script>
# Out:
# <div style="text-align: center; width: 300px;">
#   <svg width="200" height="200">
#     <!-- A rectangle with rx and ry equal to half its width/height is a circle -->
#     <rect id="morph-shape"
#           x="10" y="10"
#           width="180" height="180"
#           rx="90" ry="90"
#           fill="tomato"
#           stroke="red" stroke-width="4" />
#   </svg>
#   <br><br>
#   <input type="range" id="morph-slider" min="0" max="90" value="90" oninput="morphShape()" style="width: 100%;">
#   <p id="morph-label">Shape: Circle (rx=90)</p>
# </div>
#
# <script>
# function morphShape() {
#   let sliderValue = document.getElementById("morph-slider").value;
#   let shape = document.getElementById("morph-shape");
#   let label = document.getElementById("morph-label");
#
#   // Update the corner radius
#   shape.setAttribute("rx", sliderValue);
#   shape.setAttribute("ry", sliderValue);
#
#   // Update the label text
#   if (sliderValue == 0) {
#       label.innerText = "Shape: Square (rx=0)";
#   } else if (sliderValue == 90) {
#       label.innerText = "Shape: Circle (rx=90)";
#   } else {
#       label.innerText = "Shape: Squircle (rx=" + sliderValue + ")";
#   }
# }
# </script>

# %%
# %%html
# <canvas id="myChart"></canvas>
#
# <script src="https://cdn.jsdelivr.net/npm/chart.js"></script>
#
# <script>
# let ctx = document.getElementById('myChart');
#
# let chart = new Chart(ctx, {
#   type: 'line', // You can change this to 'bar' or 'pie'
#   data: {
#     labels: [0, 1, 2, 3, 4], // The X-axis
#     datasets: [{
#       label: 'y = x^2',
#       data: [0, 1, 4, 9, 16]  // The Y-axis
#     }]
#   }
# });
# </script>
# Out:
# <canvas id="myChart"></canvas>
#
# <script src="https://cdn.jsdelivr.net/npm/chart.js"></script>
#
# <script>
# let ctx = document.getElementById('myChart');
#
# let chart = new Chart(ctx, {
#   type: 'line', // You can change this to 'bar' or 'pie'
#   data: {
#     labels: [0, 1, 2, 3, 4], // The X-axis
#     datasets: [{
#       label: 'y = x^2',
#       data: [0, 1, 4, 9, 16]  // The Y-axis
#     }]
#   }
# });
# </script>

# %%
# %%html
# <input id="answer" type="number">
# <button onclick="check()">Submit</button>
# <p id="feedback"></p>
# <script>
#   function check() {
#     // Your grading logic here
#   }
# </script
# Out:
# <input id="answer" type="number">
# <button onclick="check()">Submit</button>
# <p id="feedback"></p>
# <script>
#   function check() {
#     // Your grading logic here
#   }
# </script

# %% [markdown]
# # Interactivity

# %%
import plotly.express as px
import pandas as pd

# Professor writes normal Python code
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp",
                 animation_frame="year", # <--- THIS CREATES A SLIDER!
                 size="pop", color="continent", hover_name="country",
                 log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b2400edd-efcd-4d3a-9209-c35e2ac32322" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2400edd-efcd-4d3a-9209-c35e2ac32322")) {                    Plotly.newPlot(                        "b2400edd-efcd-4d3a-9209-c35e2ac32322",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=Asia\u003cbr\u003eyear=1952\u003cbr\u003egdpPercap=%{x}\u003cbr\u003elifeExp=%{y}\u003cbr\u003epop=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Taiwan","Thailand","Vietnam","West Bank and Gaza","Yemen, Rep."],"legendgroup":"Asia","marker":{"color":"#636efa","size":[8425333,120447,46886859,4693836,556263527,2125900,372000000,82052000,17272000,5441766,1620914,86459025,607914,8865488,20947571,160000,1439529,6748378,800663,20092996,9182536,507833,41346560,22438691,4005677,1127000,7982342,3661549,8550362,21289402,26246839,1030585,4963829],"sizemode":"area","sizeref":435928.2961983471,"symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":[779.4453145,9867.084765,684.2441716,368.4692856,400.448611,3054.421209,546.5657493,749.6816546,3035.326002,4129.766056,4086.522128,3216.956347,1546.907807,1088.277758,1030.592226,108382.3529,4834.804067,1831.132894,786.5668575,331.0,545.8657228999998,1828.230307,684.5971437999998,1272.880995,6459.554823,2315.138227,1083.53203,1643.485354,1206.947913,757.7974177,605.0664917,1515.5923289999996,781.7175761],"xaxis":"x","y":[28.801,50.93899999999999,37.484,39.417,44.0,60.96,37.37300000000001,37.468,44.869,45.32,65.39,63.03,43.158,50.056,47.453,55.565,55.928,48.463,42.244,36.319,36.157,37.578,43.43600000000001,47.752,39.875,60.396,57.593,45.883,58.5,50.848,40.412,43.16,32.548],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=Europe\u003cbr\u003eyear=1952\u003cbr\u003egdpPercap=%{x}\u003cbr\u003elifeExp=%{y}\u003cbr\u003epop=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania","Austria","Belgium","Bosnia and Herzegovina","Bulgaria","Croatia","Czech Republic","Denmark","Finland","France","Germany","Greece","Hungary","Iceland","Ireland","Italy","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Serbia","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Turkey","United Kingdom"],"legendgroup":"Europe","marker":{"color":"#EF553B","size":[1282697,6927772,8730405,2791000,7274900,3882229,9125183,4334000,4090500,42459667,69145952,7733250,9504000,147962,2952156,47666000,413834,10381988,3327728,25730551,8526050,16630000,6860147,3558137,1489518,28549870,7124673,4815000,22235677,50430000],"sizemode":"area","sizeref":435928.2961983471,"symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":[1601.056136,6137.076492,8343.105126999999,973.5331948,2444.286648,3119.23652,6876.14025,9692.385245,6424.519071,7029.809327,7144.114393000002,3530.690067,5263.673816,7267.688428,5210.280328,4931.404154999998,2647.585601,8941.571858,10095.42172,4029.329699,3068.319867,3144.613186,3581.459448,5074.659104,4215.041741,3834.034742,8527.844662000001,14734.23275,1969.10098,9979.508487],"xaxis":"x","y":[55.23,66.8,68.0,53.82,59.6,61.21,66.87,70.78,66.55,67.41,67.5,65.86,64.03,72.49,66.91,65.94,59.164,72.13,72.67,61.31,59.82,61.05,57.996,64.36,65.57,64.94,71.86,6 ...

# %% [markdown]
# # Altair

# %%
import altair as alt
from vega_datasets import data

cars = data.cars()

chart = alt.Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    tooltip=['Name', 'Origin', 'Horsepower', 'Miles_per_Gallon']
).interactive()

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# # Pygal

# %%
# !pip install pygal
import pygal
from IPython.display import display, HTML

# Example 1: Bar Chart
bar_chart = pygal.Bar(height=400)
bar_chart.title = 'Fruit Sales by Month'
bar_chart.x_labels = ['January', 'February', 'March']
bar_chart.add('Apples', [10, 20, 30])
bar_chart.add('Bananas', [15, 25, 35])

print("Bar Chart:")
display(HTML(bar_chart.render(is_unicode=True)))

# Example 2: Pie Chart
pie_chart = pygal.Pie(height=400)
pie_chart.title = 'Browser Usage'
pie_chart.add('Chrome', 50)
pie_chart.add('Firefox', 25)
pie_chart.add('Safari', 15)
pie_chart.add('Edge', 10)

print("Pie Chart:")
display(HTML(pie_chart.render(is_unicode=True)))
# Out:
# Collecting pygal
#   Downloading pygal-3.1.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from pygal) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->pygal) (3.23.0)
# Downloading pygal-3.1.0-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: pygal
# Successfully installed pygal-3.1.0
# Bar Chart:
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-b8dbab40-da7b-4dbe-87b9-b963120c015d" class="pygal-chart" viewBox="0 0 800 400"><!--Generated with pygal 3.1.0 (lxml) ©Kozea 2012-2025 on 2026-04-04--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-b8dbab40-da7b-4dbe-87b9-b963120c015d{background-color:rgba(249,249,249,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d path,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d line,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d rect,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .graph{fill:rgba(0,0,0,.87)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d text.no_data{fill:rgba(0,0,0,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .title{fill:rgba(0,0,0,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .legends .legend text{fill:rgba(0,0,0,.87)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis .line{stroke:rgba(0,0,0,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis text.major{fill:rgba(0,0,0,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.y .guides:hover .guide.line,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .line-graph .axis.x .guides:hover .guide.line,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .stackedline-graph .axis.x .guides:hover .guide.line,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .ci{stroke:rgba(0,0,0,.87)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .reactive.active,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .ci .reactive.active{stroke-width:1.5}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .series text{fill:rgba(0,0,0,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .tooltip .label{fill:rgba(0,0,0,.87)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .tooltip .label{fill:rgba(0,0,0,.87)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .tooltip .value{font-size:1.5em}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .bound{font-size:.5em}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .color-0,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .color-1,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .text-overlay .color-0 text{fill:black}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .text-overlay .color-1 text{fill:black}
# #chart-b8dbab40-da7b-4dbe-87b9-b963120c015d text.no_data{text-anchor:middle}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .guide.line{fill:none}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .centered{text-anchor:middle}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .title{text-anchor:middle}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .legends .legend text{fill-opacity:1}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.x text{text-anchor:middle}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.x:not(.web) text[transform]{text-anchor:start}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.y text{text-anchor:end}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.y text[transform].backwards{text-anchor:start}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.y2 text{text-anchor:start}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.y2 text[transform].backwards{text-anchor:end}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .horizontal .axis.y .guide.line,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .horizontal .axis.y2 .guide.line,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .vertical .axis.x .guide.line{opacity:0}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .horizontal .axis.always_show .guide.line,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.y .guides:hover .guide.line,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.y2 .guides:hover .guide.line,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis.x .guides:hover .guide.line{opacity:1}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .axis .guides:hover text{opacity:1}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .nofill{fill:none}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .subtle-fill{fill-opacity:.2}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .dot{stroke-width:1px;fill-opacity:1;stroke-opacity:1}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .dot.active{stroke-width:5px}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .dot.negative{fill:transparent}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d text,#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d tspan{stroke:none !important}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .series text.active{opacity:1}#chart-b8dbab40-da7b-4dbe-87b9-b963120c015d .tooltip rect{fill-opa
# Pie Chart:
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d" class="pygal-chart" viewBox="0 0 800 400"><!--Generated with pygal 3.1.0 (lxml) ©Kozea 2012-2025 on 2026-04-04--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d{background-color:rgba(249,249,249,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d path,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d line,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d rect,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .graph{fill:rgba(0,0,0,.87)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d text.no_data{fill:rgba(0,0,0,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .title{fill:rgba(0,0,0,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .legends .legend text{fill:rgba(0,0,0,.87)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis .line{stroke:rgba(0,0,0,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis text.major{fill:rgba(0,0,0,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.y .guides:hover .guide.line,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .line-graph .axis.x .guides:hover .guide.line,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .stackedline-graph .axis.x .guides:hover .guide.line,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .ci{stroke:rgba(0,0,0,.87)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .reactive.active,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .ci .reactive.active{stroke-width:1.5}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .series text{fill:rgba(0,0,0,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .tooltip .label{fill:rgba(0,0,0,.87)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .tooltip .label{fill:rgba(0,0,0,.87)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .tooltip .value{font-size:1.5em}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .bound{font-size:.5em}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .color-0,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .color-1,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .color-2,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .color-2 a:visited{stroke:#009688;fill:#009688}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .color-3,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .text-overlay .color-0 text{fill:black}#chart-fd63da07 ...
# #chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d text.no_data{text-anchor:middle}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .guide.line{fill:none}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .centered{text-anchor:middle}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .title{text-anchor:middle}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .legends .legend text{fill-opacity:1}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.x text{text-anchor:middle}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.x:not(.web) text[transform]{text-anchor:start}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.y text{text-anchor:end}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.y text[transform].backwards{text-anchor:start}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.y2 text{text-anchor:start}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.y2 text[transform].backwards{text-anchor:end}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .horizontal .axis.y .guide.line,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .horizontal .axis.y2 .guide.line,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .vertical .axis.x .guide.line{opacity:0}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .horizontal .axis.always_show .guide.line,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.y .guides:hover .guide.line,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.y2 .guides:hover .guide.line,#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis.x .guides:hover .guide.line{opacity:1}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .axis .guides:hover text{opacity:1}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .nofill{fill:none}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .subtle-fill{fill-opacity:.2}#chart-fd63da07-0d7e-49cb-9d86-96a35c54d07d .dot{strok

# %% [markdown]
# # Bokeh

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Enable inline rendering for Colab/Jupyter
output_notebook()

# Create a new plot with interactive tools
p = figure(title="Bokeh Example: Line and Scatter",
           x_axis_label='X-Axis',
           y_axis_label='Y-Axis',
           tools="pan,wheel_zoom,box_zoom,reset,save")

# Add a line and circle glyphs
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], legend_label="Trend", line_width=2, color="blue")
p.scatter([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], legend_label="Points", size=10, color="red")

# Display the plot
show(p)
# Out:
#   <div id="f9e0c4cf-0b3b-4369-a5b1-b953f5b5a71b" data-root-id="p1008" style="display: contents;"></div>

# %%
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, CustomJS, Slider
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
import numpy as np

# 1. Tell Bokeh we are in Colab
output_notebook()

# 2. Generate the initial math (in Python)
x = np.linspace(0, 10, 500)
y = np.sin(x)
source = ColumnDataSource(data=dict(x=x, y=y))

# 3. Draw the plot (in Python)
plot = figure(title="Interactive Sine Wave (No Server Needed!)", width=600, height=300)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

# 4. Create the Slider (in Python)
slider = Slider(start=0.1, end=10, value=1, step=.1, title="Frequency")

# 5. THE MAGIC BRIDGE: A tiny bit of JavaScript to do the math in the browser
callback = CustomJS(args=dict(source=source, slider=slider), code="""
    const data = source.data;
    const f = slider.value;
    const x = data['x'];
    const y = data['y'];

    // Recalculate the math in the browser!
    for (let i = 0; i < x.length; i++) {
        y[i] = Math.sin(f * x[i]);
    }
    source.change.emit();
""")

# Connect the slider to the magic bridge
slider.js_on_change('value', callback)

# 6. Show the interactive widget
layout = column(slider, plot)
show(layout)
# Out:
#   <div id="a63aeb75-78f1-4357-86c7-bf2565887921" data-root-id="p1114" style="display: contents;"></div>
